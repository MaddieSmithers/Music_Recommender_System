# %% [markdown]
# # Import Data

# %%
import pandas as pd


tracks = pd.read_csv("data/tracks.csv")
artists = pd.read_csv("data/artists.csv")

# %%
artists.info()
#1,162,095 artist
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1162095 entries, 0 to 1162094
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1162095 non-null  object
#  1   followers   1162084 non-null  float64
#  2   genres      1162095 non-null  object
#  3   name        1162095 non-null  object
#  4   popularity  1162095 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 44.3+ MB

# %%
#create a set of artists from tracks dataframe 
artists_on_track_df = []
def get_artists(artists):
    ids = [x.strip() for x in artists.strip('[]').replace("'", '').split(',')]
    for id in ids:
        artists_on_track_df.append(id)

for _ in tracks['id_artists'].values:
    get_artists(_)

# %%
artists_ids_set = (set(artists_on_track_df))
#757,170 
#98,504 unique artist ids

# %%
#pull out artist data that's relevant to our tracks dataframe 
artists_subset = artists[artists['id'].isin(artists_ids_set)]

# %%
artists_subset.head(30)
# Out:
#                          id  followers  \
# 137  7DLDYPMRJ0NFPcBTlg04DE      187.0
# 138  1OCPhFtvkZDLUJJkrJfD2G      155.0
# 139  4PiJnql6Z3yQ1okaLjPHpD       12.0
# 140  7eXSIjGrfSvF1xDDIJwBxC        0.0
# 149  17OXC3oLAPMOQwqmzcsoxo      735.0
# 151  1pCXaoB8RV6mkcasIuqrsT      907.0
# 153  7frYUe4C7A42uZqCzD34Y4    53636.0
# 154  6acbdy69rtlv8m9EW31MYl    72684.0
# 155  72578usTM6Cj5qWsi471Nc   248568.0
# 157  6iv4lysB1yHXoZJ2gfqTdh      786.0
# 158  7b6Ui7JVaBDEfZB9k6nHL0   701766.0
# 163  4bvGDTEPFnllKiJaEZGuXk     6395.0
# 164  6SdRVw4NGUDFrTbWHXaUbH    30651.0
# 165  5wJ1H6ud777odtZl5gG507   211174.0
# 167  1AavJbrmyu2LqJRUmR05RY     3410.0
# 175  7rVV9d6vc4FLT752uRuk71    14660.0
# 176  0n4a5imdLBN24fIrBWoqrv   328492.0
# 189  4gdMJYnopf2nEUcanAwstx   103905.0
# 200  3r0NbTTxtCBUyxcIR4prXr    66016.0
# 201  25A5LqeSK0yH4ks5fGxbI2      426.0
# 202  6xNUn9epduXbZmCgsxutSx     1720.0
# 215  2KewEocognk3bL1lQZe45G    10609.0
# 308  2mnD3lfc9infcjV6vHIV6b        9.0
# 309  6ML6W6KnWuN4PhzVRDI3PA      706.0
# 310  38wtgSBaCeiA3hxkWuYvwy      164.0
# 311  2TPSrYAEwDwaru13NuJYVI        4.0
# 313  4662l1ZmSwzD5gDGF0I5uu      165.0
# 315  6hC3tI1R7sHgplEYPviFZY      342.0
# 318  4YodKr9jquVtUcSmB0gQEf     1338.0
# 321  7AGlWsIaI9UeK7XxvUDpcC      419.0
#
#                                                 genres  \
# 137                                                 []
# 138                                                 []
# 139                                                 []
# 140                                                 []
# 149                                                 []
# 151                                                 []
# 153     ['desi pop', 'punjabi hip hop', 'punjabi pop']
# 154  ['afro dancehall', 'afropop', 'azontobeats', '...
# 155  ['filmi', 'indian folk', 'indian rock', 'kanna...
# 157                                  ['indian fusion']
# 158  ['desi pop', 'hindi indie', 'indian indie', 'i...
# 163                                    ['indian folk']
# 164                             ['khaliji', 'sheilat']
# 165                   ['desi pop', 'modern bollywood']
# 167                         ['environmental', 'sleep']
# 175                      ['desi hip hop', 'tamil pop']
# 176  ['opm', 'pinoy hip hop', 'pinoy r&b', 'pinoy t...
# 189  ['hindi indie', 'indian indie', 'indian singer...
# 200                   ['pinoy hip hop', 'tagalog rap']
# 201                                                 []
# 202                                       ['uk drill']
# 215                                                 []
# 308                                                 []
# 309                                                 []
# 310                                                 []
# 311                                                 []
# 313                                                 []
# 315                                  ['vintage tango']
# 318                                                 []
# 321                                    ['villancicos']
#
#                                name  popularity
# 137                       Guru Dutt           2
# 138           The De Castro Sisters           8
# 139             Orchestra Sinfonica           9
# 140         Teddy Stewart Orchestra          16
# 149                      Karen Peck          22
# 151                    Stephen Hill          27
# 153                         Sultaan          53
# 154                           Phyno          51
# 155                     Raghu Dixit          52
# 157                  Shashwat Singh          56
# 158                 The Local Train          57
# 163                          Achint          49
# 164             Abdullah Al Mukhles          47
# 165                   Vishal Mishra          66
# 167         Ocean Sounds Collection          59
# 175                           Arivu          63
# 176                         Because          59
# 189                       Anuv Jain          58
# 200                        Jr Crown          59
# 201                            Sava          63
# 202                       BM X MINI          63
# 215                             C2d          58
# 308                      La Roscada           0
# 309                 Charles Stanley           3
# 310                            Uama           1
# 311                    Dolores Cava           7
# 313  Brusa y los Bombones de Murano           6
# 315                    Carlos Acuña          14
# 318                Jorge López Ruiz          13
# 321                   Los Arroyenos          15

# %%
artists[artists['id'] == "['0LyfQWJT6nXafLPZqxe9Of']"]
# Out:
# Empty DataFrame
# Columns: [id, followers, genres, name, popularity]
# Index: []

# %% [markdown]
# Since we have a lot of missing values in the genre column, we may not use this dataframe at all....

# %% [markdown]
# # Data Cleaning

# %%
tracks[tracks['name'].isna()]['id_artists'].value_counts()
#all missing values are from the same artist id...
#['0LyfQWJT6nXafLPZqxe9Of']
#since this id isn't in our artists dataframe referring to the Spotify API tells us this means "various artist" we can drop these from our dataframe
tracks.drop(tracks[tracks['name'].isna()].index, axis=0, inplace=True)

# %%
# Convert length in milliseconds to length in minutes and seconds
tracks['length_minutes'] = tracks['duration_ms'] // 60000
tracks['length_seconds'] = (tracks['duration_ms'] % 60000) // 1000

# Format the length as minutes:seconds
tracks['length_formatted'] = tracks.apply(lambda row: f"{row['length_minutes']}:{row['length_seconds']:02d}", axis=1)

# %%
tracks.drop(['length_minutes', 'length_seconds'], axis=1, inplace=True)

# %%
#clean up artists and id_artists columns
def clean_artists(artists):
    ids = [x.strip() for x in artists.strip('[]').replace("'", '').split(',')]
    return ids
    
tracks['id_artists'] = tracks['id_artists'].apply(clean_artists)

# %%
tracks['artists_cleaned'] = tracks['artists'].apply(clean_artists)

# %%
tracks['release_year'] = tracks['release_date'].apply(lambda x: x[:4])

# %%
tracks.drop('release_date', axis=1, inplace=True)

# %%
tracks.drop('artists', axis=1, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
testtest = tracks['release_year'][586644]

# %%
def make_decade(year):
    decade = year[:3]
    decade = decade + '0'
    return decade

make_decade(testtest)
# Out:
# '2010'

# %%
tracks['decade'] = tracks['release_year'].apply(make_decade)

# %%
tracks.to_csv('master_track_data.csv')

# %%
# Out:
#                             id                         name  popularity  \
# 586642  44tvGaqisGSy4Qy45vd0CF  Thousand Pieces (FYHYM2019)           1
# 586643  1932nBdtEgMpDGkpl93cS4     Saving Angel (FYHYM2019)           1
# 586650                           [7okSU80WTrn4LXlyXYbX3P]         0.493
# 586651                           [7Dx7RhX0mFuXhCOUgB01uM]         0.596
# 586652                           [2jnIB6XdLvnJUeNTy5A0J2]         0.578
# 586653                           [7Dx7RhX0mFuXhCOUgB01uM]         0.457
# 586654                           [7wLyGTO9vUS7ndlq4BvBGe]         0.317
# 586655                           [7LadOFiUVrFL5Ancq9RLtP]         0.792
# 586656                           [27kWsk6mk6DeqQhdOHsyej]         0.744
# 586657                           [7vgGpuiXdNlCmc994PlMlz]         0.609
# 586658                           [1SZdTuxme3mOk0D9pUFrET]         0.596
# 586659                           [5SWFVqjJ5POFRF6cudSL3X]         0.617
# 586660                           [1dygDSkQGQOfq1ZdChpOCs]         0.465
# 586661                           [7okSU80WTrn4LXlyXYbX3P]         0.590
# 586662                           [1lFLniFTaPjYCtQZvDXpqu]         0.476
# 586663   [7nKA1c1Qn6nI0XA8yburf3, 7g8hOWXtGS16J30CMU1SR7]         0.677
# 586664                           [6PWJWwEm8BSBFAIAUWlwe4]         0.743
# 586665                           [4MxqhahGRT4BPz1PilXGeu]         0.562
# 586666                           [4USdOnfLczwUglA3TrdHs2]         0.626
# 586667                           [1QLBXKM5GCpyQQSVMNZqrZ]         0.560
# 586668                           [1dy5WNgIKQU6ezkpZs4y8z]         0.765
# 586669                           [37M5pPGs6V1fchFJSgCguX]         0.535
# 586670   [4jGPdu95icCKVF31CcFKbS, 5ebPSE9YI5aLeZ1Z2gkqjn]         0.696
# 586671                           [0i4Qda0k4nf7jnNHmSNpYv]         0.686
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# 586642  0.9970    1    -6.145     0       0.1450      0.000239
# 586643  0.9970    6    -6.124     0       0.1940      0.000898
# 586644  0.4690    0    -7.380     1       0.0270      0.016700
# 586645  0.5680    1    -6.356     1       0.0408      0.116000
# 586646  0.3680   10   -10.436     1       0.0339      0.724000
# 586647  0.1950    2    -8.335     1       0.0440      0.958000
# 586648  0.4580    3    -6.598     1       0.0277      0.760000
# 586649  0.6730    4    -3.639     1       0.0314      0.143000
# 586650  0.4610    2    -8.524     1       0.0456      0.845000
# 586651  0.4870    7    -7.485     1       0.0309      0.654000
# 586652  0.7400    2    -5.080     1       0.0721      0.011900
# 586653  0.6790    2    -5.352     1       0.0502      0.279000
# 586654  0.5450   11    -6.439     0       0.0469      0.039000
# 586655  0.8030    0    -5.044     1       0.0443      0.333000
# 586656  0.6050    5    -5.830     0       0.0318      0.497000
# 586657  0.0172    8   -28.573     1       0.1180      0.996000
# 586658  0.5620    2    -7.314     1       0.0322      0.670000
# 586659  0.2200    6   -13.004     1       0.0301      0.580000
# 586660  0.0289    3   -27.689     1       0.0430      0.996000
# 586661  0.4430    0    -5.662     1       0.0722      0.618000
# 586662  0.4400    3    -8.508     1       0.0488      0.679000
# 586663  0.9700    0    -3.388     0       0.0446      0.134000
# 586664  0.6790    8    -3.952     1       0.0323      0.269000
# 586665  0.0331    1   -25.551     1       0.1030      0.996000
# 586666  0.5300    5   -13.117     0       0.0284      0.113000
# 586667  0.5180    0    -7.471     0       0.0292      0.785000
# 586668  0.6630    0    -5.223     1       0.0652      0.141000
# 586669  0.3140    7   -12.823     0       0.0408      0.895000
# 586670  0.6150   10    -6.212     1       0.0345      0.206000
# 586671  0.7230    6    -7.067     1       0.0363      0.105000
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 586642          0.002680    0.7560   0.0639  137.938               4
# 586643          0.872000    0.4600   0.0393  137.996               4
# 586644          0.000000    0.1110   0.2330  135.035               4
# 586645          0.000000    0.1650   0.6400  166.107               4
# 586646          0.000003    0.1110   0.3370  168.803               4
# 586647          0.000003    0.1040   0.2860   93.706               4
# 586648          0.000000    0.1330   0.3400  137.911               4
# 586649          0.000000    0.0989   0.2970  130.066               4
# 586650          0.000000    0.1150   0.3500   51.414               4
# 586651          0.000000    0.0895   0.2770   99.003               4
# 586652          0.000000    0.1800   0.4950  155.984               4
# 586653          0.000000    0.1280   0.3010  179.813               3
# 586654          0.000000    0.1160   0.1400  139.014               5
# 586655          0.000121    0.2140   0.9310  128.003               4
# 586656          0.000000    0.3940   0.4710  108.012               4
# 586657          0.973000    0.1080   0.8900   68.619               4
# 586658          0.000000    0.2020   0.3800  138.085               4
# 586659          0.004830    0.4200   0.2430  124.990               4
# 586660          0.959000    0.1360   0.4480   99.873               3
# 586661          0.000000    0.1100   0.3420  149.447               4
# 586662          0.000000    0.0926   0.2410  135.814               4
# 586663          0.002340    0.3020   0.9080  140.026               4
# 586664          0.000000    0.1330   0.3950  126.070               4
# 586665          0.961000    0.1110   0.3860   63.696               3
# 586666          0.856000    0.1040   0.2150  120.113               4
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4
#
#        length_formatted                     artists_cleaned release_year  \
# 586642             1:23  [A & Z, Claudiu Adam, Clara Yates]         2020
# 586643             2:05                  [RAM, Stine Grove]         2020
# 586644             3:23                      [Boy In Space]         2019
# 586645             2:54                     [Jordan Clarke]         2019
# 586646             5:04                         [Eric Chou]         2019
# 586647             4:03                     [Years & Years]         2020
# 586648             4:50                                [开开]         2020
# 586649             4:25                                [芝麻]         2020
# 586650             3:18                      [Clinton Kane]         2020
# 586651             4:32                            [JJ Lin]         2020
# 586652             3:15                     ["Why Dont We"]         2020
# 586653             3:52                            [JJ Lin]         2020
# 586654             3:25                        [Blake Rose]         2020
# 586655             4:05                               [小乐哥]         2020
# 586656             3:52                               [回小仙]         2020
# 586657             1:22                    [Laureen Conrad]         2020
# 586658             4:14                                [En]         2020
# 586659             6:07                               [解语花]         2020
# 586660             2:03                   [Ludovico Sagese]         2020
# 586661             3:22                      [Clinton Kane]         2020
# 586662             4:33                        [KIMSEJEONG]         2020
# 586663             2:36                            [程響, 阿卓]         2020
# 586664             3:25                       [Boon Hui Lu]         2020
# 586665             3:05                    [Gregory Oberle]         2020
# 586666             1:46                       [Emilie Chin]         2020
# 586667             4:18                           [阿YueYue]         2020
# 586668             2:33                        [ROLE MODEL]         2020
# 586669             3:07                           [FINNEAS]         2020
# 586670             2:22         [Gentle Bones, Clara Benin]         2021
# 586671             3:34                         [Afrosound]         2015
#
#        decade
# 586642   2020
# 586643   2020
# 586644   2010
# 586645   2010
# 586646   2010
# 586647   2020
# 586648   2020
# 586649   2020
# 586650   2020
# 586651   2020
# 586652   2020
# 586653   2020
# 586654   2020
# 586655   2020
# 586656   2020
# 586657   2020
# 586658   2020
# 586659   2020
# 586660   2020
# 586661   2020
# 586662   2020
# 586663   2020
# 586664   2020
# 586665   2020
# 586666   2020
# 586667   2020
# 586668   2020
# 586669   2020
# 586670   2020
# 586671   2010
